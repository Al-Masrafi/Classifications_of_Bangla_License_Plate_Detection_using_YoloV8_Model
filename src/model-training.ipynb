# %%
# !pip install ultralytics
# !pip install roboflow

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image

# %%
rf = Roboflow(api_key="9PKUVRT5NQtWlVle9Fkf")
project = rf.workspace("engineering-3bqg7").project("various-vehicles-license-plate-in-bangla-fclxg")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/kaggle/working/Various-vehicles-license-plate-in-Bangla-1/data.yaml epochs=50 imgsz=420 plots=True

# %% [markdown]
# !yolo task=detect mode=train model=yolov8s.pt data=/content/flame-1/data.yaml epochs=30 imgsz=420 plots=True

# %%
# VALIDATION
# !yolo task=detect mode=val model=/kaggle/working/runs/detect/train2/weights/best.pt data=/kaggle/working/Various-vehicles-license-plate-in-Bangla-1/data.yaml

# %%
# VIEW MODEL TRANING CHARTS
Image(filename=f'/kaggle/working/runs/detect/train2/results.png', width=600)

# %%
from IPython.display import Image

# Display the predicted image
Image(filename='/content/test.35.04 PM.jpeg')

# %%
import torch;
print(torch.__version__)

# %%
# Replace 'path/to/your/image.jpg' with the path to your image file
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source='/content/test.35.04 PM.jpeg'

# %%
from IPython.display import Image

# Display the predicted image
Image(filename='/content/runs/detect/predict2/test.35.04 PM.jpg')

# %%
from ultralytics import YOLO

# Load your trained YOLOv8 model
model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt') # Replace with the actual path to your best.pt file

# Export the model to TFLite format
# The exported model will be saved in the same directory as the original model
model.export(format='tflite')

# %%
from ultralytics import YOLO

# Load your trained YOLOv8 model
model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt') # Replace with the actual path to your best.pt file

# Export the model to TFLite format with INT8 quantization
# This might require a representative dataset for full integer quantization
model.export(format='tflite', int8=True)

# %% [markdown]
# You can download the zip file by clicking on the file icon on the left panel, navigating to `/content`, and then right-clicking on `content_archive.zip` and selecting "Download".

# %%
# Replace 'path/to/your/video.mp4' with the path to your video file in Colab
# Replace '/content/runs/detect/train3/weights/best.pt' with the actual path to your best model if it's different
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source='/content/Campfire by the River.mp4'

# %%
# Replace 'path/to/your/image.jpg' with the path to your image file
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt source='/content/test image/images.jpg'

# %%
import shutil
import os

# Define the source directory where your trained models are located
# This is typically in the runs/detect/train directory
source_dir = '/content/runs/detect'

# Define the destination directory in your Google Drive
# Make sure to replace 'Your_Model_Folder' with the desired folder name in your Drive
destination_dir = '/content/drive/MyDrive/Bangla_Name_Plate_detection_Trained_model'

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Copy the entire training results directory to your Google Drive
shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)

print(f"Trained models copied from {source_dir} to {destination_dir}")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import shutil
import os

# Remove the existing /content/drive directory if it exists
if os.path.exists('/content/drive'):
    shutil.rmtree('/content/drive')
    print("Removed existing /content/drive directory.")

# Now attempt to mount Google Drive again
from google.colab import drive
drive.mount('/content/drive')

# %%
# Zip the entire /kaggle/working/ directory for easy download
# !zip -r file.zip /kaggle/working/runs
